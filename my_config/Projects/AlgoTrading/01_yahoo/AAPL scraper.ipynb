# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# %%
ticker = "AAPL"

end = datetime.now()
start = end - timedelta(days=30)

chunk_days = 7

dfs = []

# %%
current_start = start

while current_start<end:
    current_end = min(current_start + timedelta(days=chunk_days) ,end)
    print(f"Downloading -> {current_start} to {current_end}")

    df = yf.download(
        ticker, 
        start = current_start,
        end = current_end, 
        interval = "1m",
        progress = False
        )

    if not df.empty:
        dfs.append(df)

    current_start = current_end
# Out:
# Downloading -> 2026-01-21 06:50:02.683843 to 2026-01-28 06:50:02.683843
# Downloading -> 2026-01-28 06:50:02.683843 to 2026-02-04 06:50:02.683843
# Downloading -> 2026-02-04 06:50:02.683843 to 2026-02-11 06:50:02.683843
# Downloading -> 2026-02-11 06:50:02.683843 to 2026-02-18 06:50:02.683843
# Downloading -> 2026-02-18 06:50:02.683843 to 2026-02-20 06:50:02.683843

# %%
data = pd.concat(dfs)
data = data[~data.index.duplicated(keep="first")]
data = data.reset_index()

data.to_csv("aapl_1y_1m.csv", index=False)

print("Done. Rows:", len(data))
# Out:
# Done. Rows: 7553
